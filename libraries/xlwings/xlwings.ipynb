# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf
from datetime import datetime

# %%
def retrieve_stock_data(ticker_symbol):
    yf.pdr_override()
    start=datetime.strptime('2020-12-01',"%Y-%m-%d")
    end=datetime.strptime('2020-12-31',"%Y-%m-%d")
    df = pdr.get_data_yahoo(ticker_symbol, start,end)
    return df
df=retrieve_stock_data('TSLA')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-12-01  199.196671  199.283340  190.683334  194.919998  194.919998  \
# 2020-12-02  185.479996  190.513336  180.403336  189.606674  189.606674
# 2020-12-03  196.673340  199.656662  194.143326  197.793335  197.793335
# 2020-12-04  197.003326  199.679993  195.166672  199.679993  199.679993
# 2020-12-07  201.639999  216.263336  201.016663  213.919998  213.919998
#
#                Volume
# Date
# 2020-12-01  120310500
# 2020-12-02  143327100
# 2020-12-03  127656000
# 2020-12-04   88203900
# 2020-12-07  168929100

# %%
mpg=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0  \
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
import xlwings as xw

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 0    18.0          8         307.0       130.0    3504          12.0  \
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
xw.view(mpg)
# Out:
# ---------------------------------------------------------------------------
# XlwingsError                              Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 xw.view(mpg)
#
# File ~/.cache/pypoetry/virtualenvs/learnpython-3LpIPjun-py3.8/lib/python3.8/site-packages/xlwings/main.py:4709, in view(obj, sheet, table, chunksize)
#    4670 """
#    4671 Opens a new workbook and displays an object on its first sheet by default. If you
#    4672 provide a sheet object, it will clear the sheet before displaying the object on the
#    (...)
#    4706 .. versionchanged:: 0.22.0
#    4707 """
#    4708 if sheet is None:
# -> 4709     sheet = Book().sheets.active
#    4710 else:
#    4711     sheet.clear()
#
# File ~/.cache/pypoetry/virtualenvs/learnpython-3LpIPjun-py3.8/lib/python3.8/site-packages/xlwings/main.py:953, in Book.__init__(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load, impl, json, mode, engine)
#     950         impl = candidates[0][1].impl
#     951 else:
#     952     # Open Excel if necessary and create a new workbook
# --> 953     if apps.active:
#     954         impl = apps.active.books.add().impl
#     955     else:
#
# File ~/.cache/pypoetry/virtualenvs/learnpython-3LpIPjun-py3.8/lib/python3.8/site-packages/xlwings/main.py:219, in Apps.active(self)
#     212 @property
#     213 def active(self):
#     214     """
#     215     Returns the active app.
#     216
#     217     .. versionadded:: 0.9.0
#     218     """
# --> 219     for app in self.impl:
#     220         return App(impl=app)
#     221     return None
#
# File ~/.cache/pypoetry/virtualenvs/learnpython-3LpIPjun-py3.8/lib/python3.8/site-packages/xlwings/main.py:5157, in ActiveEngineApps.impl(self)
#    5153 if engines.active is None:
#    5154     if not (
#    5155         sys.platform.startswith("darwin") or sys.platform.startswith("win")
#    5156     ):
# -> 5157         raise XlwingsError(
#    5158             "The interactive mode of xlwings is only supported on Windows and "
#    5159             "macOS. On Linux, you can use xlwings Server or xlwings Reader."
#    5160         )
#    5161     elif sys.platform.startswith("darwin"):
#    5162         raise XlwingsError(
#    5163             'Make sure to have "appscript" and "psutil", '
#    5164             "dependencies of xlwings, installed."
#    5165         )
#
# XlwingsError: The interactive mode of xlwings is only supported on Windows and macOS. On Linux, you can use xlwings Server or xlwings Reader.
